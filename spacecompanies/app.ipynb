# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json as json

# %%
with open('spaceCompanies.json','r') as json_file :

    ddata = json.load(json_file)

# %%
pd.DataFrame(ddata['companies'])
# Out:
#                           _id  \
# 0    58caff366ed7bb3c6ee62d16
# 1    58d163cd6ed7bb3c6ee62e63
# 2    58d2bcc36ed7bb3c6ee62ebc
# 3    58d2e0a56ed7bb3c6ee62f04
# 4    58d37e276ed7bb3c6ee62fa7
# ..                        ...
# 149  5fc622ed7d4cc4392b19d7f4
# 150  5fff03e7975ca80e320d443f
# 151  600737136739ef1c3b04e5f0
# 152  600833e33b2b9b72c4662c25
# 153  6011d10b6c2daf044dd2d7b6
#
#                                                company  \
# 0    {'_id': '58caff7d6ed7bb3c6ee62d17', 'about': '...
# 1    {'_id': '58d164516ed7bb3c6ee62e64', 'about': '...
# 2    {'_id': '58d2bd156ed7bb3c6ee62ebd', 'about': '...
# 3    {'_id': '58d2e3446ed7bb3c6ee62f05', 'about': '...
# 4    {'_id': '58d37ead6ed7bb3c6ee62faa', 'about': '...
# ..                                                 ...
# 149  {'_id': '5fc623237d4cc4392b19d7f6', 'companyLo...
# 150  {'_id': '5fff03f2975ca80e320d4442', 'companyLo...
# 151  {'_id': '600737546739ef1c3b04ea73', 'about': '...
# ...

# %%
# Out:
#                                              companies  success
# 0    {'_id': '58caff366ed7bb3c6ee62d16', 'company':...     True
# 1    {'_id': '58d163cd6ed7bb3c6ee62e63', 'company':...     True
# 2    {'_id': '58d2bcc36ed7bb3c6ee62ebc', 'company':...     True
# 3    {'_id': '58d2e0a56ed7bb3c6ee62f04', 'company':...     True
# 4    {'_id': '58d37e276ed7bb3c6ee62fa7', 'company':...     True
# ..                                                 ...      ...
# 149  {'_id': '5fc622ed7d4cc4392b19d7f4', 'company':...     True
# 150  {'_id': '5fff03e7975ca80e320d443f', 'company':...     True
# 151  {'_id': '600737136739ef1c3b04e5f0', 'company':...     True
# 152  {'_id': '600833e33b2b9b72c4662c25', 'company':...     True
# 153  {'_id': '6011d10b6c2daf044dd2d7b6', 'company':...     True
#
# [154 rows x 2 columns]
